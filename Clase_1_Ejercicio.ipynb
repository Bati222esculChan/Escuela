# %% [markdown]
# <a href="https://colab.research.google.com/github/Bati222esculChan/Escuela/blob/main/Clase_1_Ejercicio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#print es el comando que utilizo para comunicarme con el usuario
nombre = input("Dame tu nombre: ")
edad = int(input("Dame tu edad: "))

# %%
print("Hola", nombre, "Bienvenido")
print("tu edad es", edad, "años")

# %%
print("hola", nombre, "Bienvenido")
print("tu edad es", edad, "años de edad")
print("Tu edad en un año sera: ", int(edad)+1)
