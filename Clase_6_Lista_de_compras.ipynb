# %% [markdown]
# <a href="https://colab.research.google.com/github/Bati222esculChan/Escuela/blob/main/Clase_6_Lista_de_compras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
paises = ["MEXICO, " "ESTADOS UNIDOS", "ARGENTINA", "ISRAEL"]

paises.append("CHINA")
paises.insert(0, "MEXICO")
paises.remove("ISRAEL")
paises.pop(2)
paises.insert(3, "FRANCIA")
print(paises)

['MEXICO', 'ESTADOS UNIDOS', 'ARGENTINA', 'ISRAEL', 'CHINA', 'FRANCIA']
# Out:
# ['MEXICO', 'MEXICO, ESTADOS UNIDOS', 'CHINA', 'FRANCIA']
# ['MEXICO', 'ESTADOS UNIDOS', 'ARGENTINA', 'ISRAEL', 'CHINA', 'FRANCIA']

# %%
compras = []
compras.append("leche")
compras.append("pan")
compras.append("huevos")
compras.append("carne")
compras.insert(1, "manzanas")
print("Lista Completa: ", compras)
compras.pop()
compras.sort()
print("Lista Ordenada: ", compras)
print("Cantidad de cosas:", len(compras))
# Out:
# Lista Completa:  ['leche', 'manzanas', 'pan', 'huevos', 'carne']
# Lista Ordenada:  ['huevos', 'leche', 'manzanas', 'pan']
# Cantidad de cosas: 4
