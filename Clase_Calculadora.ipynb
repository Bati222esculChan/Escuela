# %% [markdown]
# <a href="https://colab.research.google.com/github/Bati222esculChan/Escuela/blob/main/Clase_Calculadora.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Bienvenido a la calculadora")
print("Estas en la suma")
numero1 = int(input("Dame el primer numero"))
numero2 = int(input("Dame el segundo numero"))

print("el resultado de la suma", numero1+numero2)

#Los int convierte los numeros en numero entero
# Out:
# Bienvenido a la calculadora
# Estas en la suma
# Dame el primer numero2
# Dame el segundo numero3
# el resultadode la suma 5

# %%
print("Bienvenido a la calculadora")
print("Estas en la multiplicacion")
numero1 = int(input("Dame el primer numero"))
numero2 = int(input("Dame el segundo numero"))

print("el resultado de la multiplicacion", numero1*numero2)
# Out:
# Bienvenido a la calculadora
# Estas en la multiplicacion
# Dame el primer numero2
# Dame el segundo numero3
# el resultado de la multiplicacion 6

# %%
print("Bienvenido a la division")
print("Estas en la division")
numero1 = int(input("Dame el primer numero"))
numero2 = int(input("Dame el segundo numero"))

print("el resultado de la division", numero1/numero2)
# Out:
# Bienvenido a la division
# Estas en la division
# Dame el primer numero5
# Dame el segundo numero2
# el resultado de la division 2.5
