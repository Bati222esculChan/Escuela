# %% [markdown]
# <a href="https://colab.research.google.com/github/Bati222esculChan/Escuela/blob/main/Clase_3_Actividades.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Cual es tu edad?  ")
edad = int(input("Dame tu edad "))
if edad == 0:
  print("Recien nacido")
elif edad == 1 and edad == 2:
    print("BEBE")
elif edad >= 3 and edad <= 11:
  print("NIÑO")
elif edad >= 12 and edad <= 17:
  print("ADOLESCENTE")
elif edad >= 18:
  print("che viejo loco")
  while edad >= 0:
    print("No se puede")
    while True
# Out:
# Cual es tu edad?
# Dame tu edad -2

# %%
lista_participantes = []

cantidad = int(input("¿Cuántos participantes son? "))

for i in range(cantidad):
    nombre = input("Dame el nombre del participante: ")
    edad = int(input("Dame la edad del participante: "))
    lista_participantes.append([nombre, edad])

print(lista_participantes)
# Out:
# ¿Cuántos participantes son? 2
# Dame el nombre del participante: Diego
# Dame la edad del participante: 12
# Dame el nombre del participante: lUIS
# Dame la edad del participante: 3
# [['Diego', 12], ['lUIS', 3]]

# %%
#while y do while calajo a ver qpd
