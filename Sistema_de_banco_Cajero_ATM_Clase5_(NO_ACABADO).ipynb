# %% [markdown]
# <a href="https://colab.research.google.com/github/Bati222esculChan/Escuela/blob/main/Sistema_de_banco_Cajero_ATM_Clase5_(NO_ACABADO).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Ponerle comillas es porque es un string
if Ver datos = 1:
saldo = 3000
cuenta = "1234"
NIP = "707070"

intento = input("Escribe el NIP: ")
while intento != nip:
  intento = input("Nip incorrecto, vuelve a intentarlo: ")

print("Bienvenido")
print("Opciones")
print("1.Ver datos" )
print("2.Retirar" )
print("3.Abonar" )
print("4.Salir" )

while opcion != "1" and opcion != "2" and opcion != "3" and opcion != "4":
  print("Opcion incorrecta")
  opcion = input("¿Que quieres hacer hoy? ")

  if opcion == "1":
    print("Saldo: " + saldo)
    print("Cuenta: " + cuenta)
  elif opcion == "2":
    print("¿Cuanto quieres retirar?")
    retirar = saldo -
# Out:
# Sistema de cajero
# 1.Ver datos
# 2.Retirar
# 3.Abonar
# 4.Salir
# ¿Que quieres hacer hoy? 2
# 2
